# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_excel('spotifydata.xlsx', skiprows=20, skipfooter=2)
# Out:
#        Movie              Amalya  \
# 0      Movie   Martin & les fées
# 1      Movie            Dorothée
# 2      Movie      Henri Salvador
# 3      Movie  Jean Claude Corbel
# 4      Movie      Henri Salvador
# ...      ...                 ...
# 16356  Dance                P!nk
# 16357  Dance               Loote
# 16358  Dance            Dua Lipa
# 16359  Dance              Avicii
# 16360  Dance       Ariana Grande
#
#                                     Ladies And Gentlemen  \
# 0      Tout est possible (par Anggun, Dany Brillant, ...
# 1                                         Clic clac cloc
# 2                                     Monsieur Boum Boum
# 3                             Pourquoi aller plus loin ?
# 4                                Quand je monte chez toi
# ...                                                  ...
# 16356                                        Where We Go
# 16357            Longer Than I Thought (feat. Joe Jonas)
# ...

# %%
sd = pd.read_excel('spotifydata.xlsx', skiprows=20, skipfooter=2)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 2)
sd
# Out:
#        Movie              Amalya  \
# 0      Movie   Martin & les fées
# 1      Movie            Dorothée
# 2      Movie      Henri Salvador
# 3      Movie  Jean Claude Corbel
# 4      Movie      Henri Salvador
# ...      ...                 ...
# 16356  Dance                P!nk
# 16357  Dance               Loote
# 16358  Dance            Dua Lipa
# 16359  Dance              Avicii
# 16360  Dance       Ariana Grande
#
#                                     Ladies And Gentlemen  \
# 0      Tout est possible (par Anggun, Dany Brillant, ...
# 1                                         Clic clac cloc
# 2                                     Monsieur Boum Boum
# 3                             Pourquoi aller plus loin ?
# 4                                Quand je monte chez toi
# ...                                                  ...
# 16356                                        Where We Go
# 16357            Longer Than I Thought (feat. Joe Jonas)
# ...

# %%
sd.head()
# Out:
#    Movie              Amalya  \
# 0  Movie   Martin & les fées
# 1  Movie            Dorothée
# 2  Movie      Henri Salvador
# 3  Movie  Jean Claude Corbel
# 4  Movie      Henri Salvador
#
#                                 Ladies And Gentlemen  12ZjoNweObu1k9rK4SOSdL  \
# 0  Tout est possible (par Anggun, Dany Brillant, ...  12hJJLMMbJDK0F9I3g5SLv
# 1                                     Clic clac cloc  148uA2Y78xfxDiCNjgZA0v
# 2                                 Monsieur Boum Boum  14K25Ks5fdHjHfpIYOTc4y
# 3                         Pourquoi aller plus loin ?  15CpJP0LXchBUjpB8RKh8m
# 4                            Quand je monte chez toi  15nBPcHoH2fZmRiFd2ZhMh
#
#    4  0.161  0.522  207240  0.748  7.25e-06 C#  0.111  -5.203  Major  0.0824  \
# 0  1   0.85   0.36  219600   0.44      0.00  C   0.09   -6.97  Major    0.03
# 1  1   0.51   0.85  183467   0.50      0.00  D   0.08  -12.36  Major    0.07
# 2  8   0.69   0.70  161773   0.80      0.04  C   0.18   -6.70  Major    0.11
# ...

# %%
sd.tail()
# Out:
#        Movie         Amalya                     Ladies And Gentlemen  \
# 16356  Dance           P!nk                              Where We Go
# 16357  Dance          Loote  Longer Than I Thought (feat. Joe Jonas)
# 16358  Dance       Dua Lipa        Lost In Your Light (feat. Miguel)
# 16359  Dance         Avicii                             Feeling Good
# 16360  Dance  Ariana Grande                           Last Christmas
#
#        12ZjoNweObu1k9rK4SOSdL   4     0.161  0.522  207240  0.748  7.25e-06  \
# 16356  4kUHQ01RTSbI75az5hjdOR  62  8.34e-03   0.64  267493   0.74  0.00e+00
# 16357  1hPwlWlrGzcavwBCcS2gDD  61  8.71e-02   0.76  215827   0.72  4.57e-06
# 16358  1v3bR4v6SruaE8efrTUqqp  65  4.02e-04   0.65  203769   0.77  0.00e+00
# 16359  7rc6L3UtM0uvwfpsl07GBL  63  3.37e-01   0.45  228939   0.59  0.00e+00
# 16360  5xDrO9DEDJGUQGfyoHvgDJ  60  1.27e-01   0.68  203653   0.79  0.00e+00
#
#        C#  0.111  -5.203  Major  0.0824  184.063  2023-04-04 00:00:00  0.733
# ...

# %%
sd[:10]
# Out:
#    Movie              Amalya  \
# 0  Movie   Martin & les fées
# 1  Movie            Dorothée
# 2  Movie      Henri Salvador
# 3  Movie  Jean Claude Corbel
# 4  Movie      Henri Salvador
# 5  Movie           Jean Piat
# 6  Movie      Henri Salvador
# 7  Movie        Lucie Dolene
# 8  Movie      Henri Salvador
# 9  Movie              Chorus
#
#                                 Ladies And Gentlemen  12ZjoNweObu1k9rK4SOSdL  \
# 0  Tout est possible (par Anggun, Dany Brillant, ...  12hJJLMMbJDK0F9I3g5SLv
# 1                                     Clic clac cloc  148uA2Y78xfxDiCNjgZA0v
# 2                                 Monsieur Boum Boum  14K25Ks5fdHjHfpIYOTc4y
# 3                         Pourquoi aller plus loin ?  15CpJP0LXchBUjpB8RKh8m
# 4                            Quand je monte chez toi  15nBPcHoH2fZmRiFd2ZhMh
# 5                               Comme minuit sonnait  16UTNMhXjeJa8IG9uBijxZ
# 6                                          Le Fêtard  16hVzfu0IJZmP3Bj4x1BB1
# ...

# %%
sd.iloc[30, :5]
# Out:
# Movie                                      Movie
# Amalya                              Claire Guyot
# Ladies And Gentlemen                  Le silence
# 12ZjoNweObu1k9rK4SOSdL    24XhoLQObCUbk4ybOWtrZl
# 4                                              1
# Name: 30, dtype: object

# %%
print(sd.columns.tolist())
# Out:
# ['Movie', 'Amalya', 'Ladies And Gentlemen', '12ZjoNweObu1k9rK4SOSdL', 4, 0.161, 0.522, 207240, 0.748, 7.25e-06, 'C#', 0.111, -5.203, 'Major', 0.0824, 184.063, datetime.datetime(2023, 4, 4, 0, 0), 0.733]

# %%
sd.describe()
# Out:
#               4     0.161     0.522    207240     0.748  7.25e-06     0.111  \
# count  16361.00  1.64e+04  16361.00  1.64e+04  1.64e+04  1.64e+04  16361.00
# mean      49.30  2.12e-01      0.57  2.28e+05  6.72e-01  3.91e-02      0.19
# std       14.17  2.63e-01      0.14  8.03e+04  2.09e-01  1.44e-01      0.16
# min        0.00  1.39e-06      0.06  1.88e+04  1.54e-03  0.00e+00      0.02
# 25%       41.00  1.02e-02      0.48  1.93e+05  5.24e-01  0.00e+00      0.10
# 50%       48.00  8.50e-02      0.57  2.19e+05  7.00e-01  7.57e-06      0.13
# 75%       58.00  3.38e-01      0.67  2.51e+05  8.45e-01  9.41e-04      0.25
# max      100.00  9.96e-01      0.97  3.63e+06  9.98e-01  9.84e-01      1.00
#
#          -5.203    0.0824   184.063     0.733
# count  16361.00  16361.00  16361.00  16361.00
# mean      -6.89      0.08    121.92      0.48
# std        3.14      0.09     29.67      0.23
# min      -30.02      0.02     32.24      0.00
# 25%       -8.32      0.03     97.85      0.31
# ...

# %%
pd.isnull(sd).sum()
# Out:
# Movie                     0
# Amalya                    0
# Ladies And Gentlemen      0
# 12ZjoNweObu1k9rK4SOSdL    0
# 4                         0
# 0.161                     0
# 0.522                     0
# 207240                    0
# 0.748                     0
# 7.25e-06                  0
# C#                        0
# 0.111                     0
# -5.203                    0
# Major                     0
# 0.0824                    0
# 184.063                   0
# 2023-04-04 00:00:00       0
# 0.733                     0
# dtype: int64

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16361 entries, 0 to 16360
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Movie                   16361 non-null  object
#  1   Amalya                  16361 non-null  object
#  2   Ladies And Gentlemen    16361 non-null  object
#  3   12ZjoNweObu1k9rK4SOSdL  16361 non-null  object
#  4   4                       16361 non-null  int64
#  5   0.161                   16361 non-null  float64
#  6   0.522                   16361 non-null  float64
#  7   207240                  16361 non-null  int64
#  8   0.748                   16361 non-null  float64
#  9   7.25e-06                16361 non-null  float64
#  10  C#                      16361 non-null  object
#  11  0.111                   16361 non-null  float64
#  12  -5.203                  16361 non-null  float64
#  13  Major                   16361 non-null  object
# ...

# %%
sd.describe().transpose()
# Out:
#             count       mean       std       min        25%       50%  \
# 4         16361.0      49.30     14.17  0.00e+00      41.00  4.80e+01
# 0.161     16361.0       0.21      0.26  1.39e-06       0.01  8.50e-02
# 0.522     16361.0       0.57      0.14  6.17e-02       0.48  5.72e-01
# 207240    16361.0  227611.69  80303.16  1.88e+04  193107.00  2.19e+05
# 0.748     16361.0       0.67      0.21  1.54e-03       0.52  7.00e-01
# 7.25e-06  16361.0       0.04      0.14  0.00e+00       0.00  7.57e-06
# 0.111     16361.0       0.19      0.16  2.05e-02       0.10  1.30e-01
# -5.203    16361.0      -6.89      3.14 -3.00e+01      -8.32 -6.19e+00
# 0.0824    16361.0       0.08      0.09  2.23e-02       0.03  4.55e-02
# 184.063   16361.0     121.92     29.67  3.22e+01      97.85  1.20e+02
# 0.733     16361.0       0.48      0.23  0.00e+00       0.31  4.72e-01
#
#                75%       max
# 4         5.80e+01  1.00e+02
# 0.161     3.38e-01  9.96e-01
# 0.522     6.69e-01  9.71e-01
# ...

# %%
sd.columns
# Out:
# Index([                 'Movie',                 'Amalya',
#          'Ladies And Gentlemen', '12ZjoNweObu1k9rK4SOSdL',
#                               4,                    0.161,
#                           0.522,                   207240,
#                           0.748,                 7.25e-06,
#                            'C#',                    0.111,
#                          -5.203,                  'Major',
#                          0.0824,                  184.063,
#             2023-04-04 00:00:00,                    0.733],
#       dtype='object')

# %%
import pandas as pd

# Load your data into the DataFrame 'sd'
# Replace 'your_data.csv' with the actual path or method you use to load your data.
sd = pd.read_excel('spotifydata.xlsx')

# Check the column names
print(sd.columns)

# Check the data types
print(sd.dtypes)

# Filter and sort the DataFrame
most_popular = sd.query('popularity > 90', inplace=False).sort_values('popularity', ascending=False)

# Display the top 10 rows
print(most_popular[:10])
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')
# genre                object
# artist_name          object
# track_name           object
# track_id             object
# popularity            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo               float64
# time_signature       object
# valence             float64
# dtype: object
#       genre    artist_name                                      track_name  \
# ...

# %%
most_popular = sd.query('popularity>90', inplace=False).sort_values('popularity', ascending = False)
most_popular[:10]
# Out:
#       genre    artist_name                                      track_name  \
# 9027  Dance  Ariana Grande                                         7 rings
# 9026  Dance  Ariana Grande        break up with your girlfriend, i'm bored
# 9028  Dance         Halsey                                      Without Me
# 9037  Dance        Ava Max                                Sweet but Psycho
# 9048  Dance       DJ Snake  Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# 9040  Dance      Lady Gaga                                         Shallow
# 9031  Dance  Ariana Grande                                   thank u, next
# 9063  Dance  Calvin Harris                     Giant (with Rag'n'Bone Man)
# 9036  Dance           Lauv                                 i'm so tired...
# 9039  Dance  Alec Benjamin                              Let Me Down Slowly
#
#                     track_id  popularity  acousticness  danceability  \
# 9027  14msK75pk3pA33pzPVNtBF         100          0.58          0.72
# ...

# %%
sorted_sd = sd.sort_values('popularity', ascending = True).head(10)
sorted_sd
# Out:
#              genre     artist_name  \
# 0            Movie  Henri Salvador
# 403          Movie        Ken Page
# 530          Movie    George Bruns
# 531          Movie          Chorus
# 848        Country      Big & Rich
# 849        Country  Tracy Lawrence
# 851        Country      Big & Rich
# 404          Movie          Chorus
# 10711  Alternative        Grizfolk
# 533          Movie          Chorus
#
#                                               track_name  \
# 0                            C'est beau de faire un Show
# 403                                      J'ai Deux Amour
# 530                                        There You Are
# 531                                          Dakhin Hawa
# 848                                                 Loud
# 849                                If the Good Die Young
# 851                                     Lay It All On Me
# 404        La Sonnambula: Tutto è gioia (Act I, scene 1)
# ...

# %%
sd["duration"] = sd["duration_ms"].apply(lambda x: round(x/1000))
sd.drop("duration_ms", inplace=True, axis=1)

# %%
sd.duration.head()
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# Name: duration, dtype: int64

# %%
sample_df = sd.sample(int(0.004*len(sd)))

# %%
print(len(sd))
# Out:
# 16383

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = sample_df, y ='loudness', x = 'energy', color = 'c').set(title = 'Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = sample_df, y ='popularity', x = 'acousticness', color = 'b').set(title = 'Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %%
sd['dates'] = sd.index.get_level_values('release_date')
sd.dates = pd.to_datetime(sd.dates)
years = sd.dates.dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Dell\OneDrive\Documents\spotifydataanalysis\pandas_basics.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/OneDrive/Documents/spotifydataanalysis/pandas_basics.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> sd['dates'] = sd.index.get_level_values('release_date')
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/OneDrive/Documents/spotifydataanalysis/pandas_basics.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> sd.dates = pd.to_datetime(sd.dates)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/OneDrive/Documents/spotifydataanalysis/pandas_basics.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> years = sd.dates.dt.year
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\indexes\base.py:1989, in Index._get_level_values(self, level)
#    1953 def _get_level_values(self, level) -> Index:
#    1954     """
# ...

# %%
sns.displot(years, discrete = True, aspect=2, height=5, kind='hist').set(title='Number Of Songs Per Year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\OneDrive\Documents\spotifydataanalysis\pandas_basics.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/OneDrive/Documents/spotifydataanalysis/pandas_basics.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> sns.displot(years, discrete = True, aspect=2, height=5, kind='hist').set(title='Number Of Songs Per Year')
#
# NameError: name 'years' is not defined

# %%
plt.figure(figsize=(30,3), dpi=300)
plt.bar('artist_name', 'genre', data=sd)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30, 3), dpi=300)
plt.bar(sd['track_name'], sd['genre'])
plt.xticks(rotation=90)
plt.xlabel('track_name')  # Change the x-axis label
plt.ylabel('genre')
plt.title('Bar Chart of genre by artist_name')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'track_name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# add to pandas dataframe row wise

# %%
small_df1 = sd[:10]
small_df2 = sd[185:]

# %%
pd.concat([small_df1, small_df2])
# Out:
#        Movie              Amalya  \
# 0      Movie   Martin & les fées
# 1      Movie            Dorothée
# 2      Movie      Henri Salvador
# 3      Movie  Jean Claude Corbel
# 4      Movie      Henri Salvador
# ...      ...                 ...
# 16356  Dance                P!nk
# 16357  Dance               Loote
# 16358  Dance            Dua Lipa
# 16359  Dance              Avicii
# 16360  Dance       Ariana Grande
#
#                                     Ladies And Gentlemen  \
# 0      Tout est possible (par Anggun, Dany Brillant, ...
# 1                                         Clic clac cloc
# 2                                     Monsieur Boum Boum
# 3                             Pourquoi aller plus loin ?
# 4                                Quand je monte chez toi
# ...                                                  ...
# 16356                                        Where We Go
# 16357            Longer Than I Thought (feat. Joe Jonas)
# ...

# %%
plt.bar('track_name', 'popularity' ,data=sd.head(10))
plt.xticks(rotation=90)
plt.show()
